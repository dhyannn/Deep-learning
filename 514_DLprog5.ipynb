# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
from sklearn.model_selection import train_test_split

# %%
def load_images(folder):
    images = []
    for filename in os.listdir(folder):
        img = mpimg.imread(os.path.join(folder, filename))
        if img is not None:
            images.append(img)
    return images

# %%
path = r"C:\Users\dhyan\animals_dataset"

# %%
categories = ['Buffalo', 'Elephant', 'Rhino', 'Zebra']
category_images = {}

# %%
# Load images for each category
for category in categories:
    folder_path = os.path.join(path, category)
    category_images[category] = load_images(folder_path)

# %%
num_images_to_display = 3
for category, images in category_images.items():
    print(f"Category: {category}")
    for i in range(min(num_images_to_display, len(images))):
        plt.imshow(images[i])
        plt.axis('off')  # Hide axes
        plt.show()
# Out:
# Category: Buffalo
# Category: Elephant
# Category: Rhino
# Category: Zebra

# %%
from PIL import Image
import os

def resize_images_pil(path, target_size=(64, 64)):
    for filename in os.listdir(path):
        img_path = os.path.join(path, filename)
        if os.path.isfile(img_path) and filename.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp')):
            try:
                img = Image.open(img_path)
                resized_img = img.resize(target_size, Image.ANTIALIAS)
                resized_img.save(img_path)
            except Exception as e:
                print(f"Error processing {img_path}: {str(e)}")

resize_images_pil(folder_path, target_size=(128, 128))
# Out:
# C:\Users\dhyan\AppData\Local\Temp\ipykernel_7456\3133619861.py:10: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   resized_img = img.resize(target_size, Image.ANTIALIAS)

# %%
import matplotlib.pyplot as plt
import os

def display_resized_images(folder_path):
    for filename in os.listdir(folder_path):
        img_path = os.path.join(folder_path, filename)
        if os.path.isfile(img_path) and filename.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp')):
            try:
                img = plt.imread(img_path)
                plt.imshow(img)
                plt.axis('off')
                plt.show()
            except Exception as e:
                print(f"Error displaying {img_path}: {str(e)}")

# Example usage:
folder_path = r"C:\Users\dhyan\animals_dataset"
display_resized_images(folder_path)

# %%
display_resize_images
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 display_resize_images
#
# NameError: name 'display_resize_images' is not defined
